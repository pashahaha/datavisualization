# %% [markdown]
# <a href="https://colab.research.google.com/github/pashahaha/datavisualization/blob/main/Matplotlib_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3,7],[1,2,4,5], color="red")
